# %%
a = int(input("Enter number1: "))
b = int(input("Enter number2: "))
c = int(input("Enter number3: "))
if(a>=b and a>=c):
    print(a , "is larger number")
elif(b>=c):
    print(b , "is larger number")
else:
    print(c , "is larger number")
# Out:
# Enter number1:  3
# Enter number2:  4
# Enter number3:  5
# 5 is larger number

# %%
yr = int(input("Enter year: "))
if((yr%4 == 0 and yr%100 !=0) or (yr%400 == 0)):
    print(yr, " is leap year")
else:
    print(yr, " is not leap year")
# Out:
# Enter year:  2024
# 2024  is leap year

# %%
ch = input("Enter character: ")
if(ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u' or ch =='A' or ch == 'E' or ch == 'I' or ch == 'O' or ch == 'U'):
    print(ch, " is vowel")
else:
    print(ch, " is consonant")
# Out:
# Enter character:  w
# w  is consonant

# %%
n = int(input("Enter number: "))
if(n%5 == 0 and n%11 == 0):
    print(n, " is divisble by both 5 and 11")
else:
    print(n, " is not divisible by both 5 and 11")
# Out:
# Enter number:  55
# 55  is divisble by both 5 and 11

# %%
n = int(input("Enter number: "))
sum = 0
while(n>0):
    sum = n + sum
    n = n-1
print("Sum is: ",sum)
# Out:
# Enter number:  5
# Sum is:  15

# %%
n = int(input("Enter number: "))
i=1
while(i<=10):
    print(n, " * ",i," = ",n*i)
    i +=1
# Out:
# Enter number:  4
# 4  *  1  =  4
# 4  *  2  =  8
# 4  *  3  =  12
# 4  *  4  =  16
# 4  *  5  =  20
# 4  *  6  =  24
# 4  *  7  =  28
# 4  *  8  =  32
# 4  *  9  =  36
# 4  *  10  =  40

# %%
cnt = 4
for i in range(1,8,2):
    cnt -= 1
    print(" " *cnt , "*" * i)
# Out:
#     *
#    ***
#   *****
#  *******

# %%
for i in range(1,6):
    for j in range(1, i+1):
        print(j, end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
